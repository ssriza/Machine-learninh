# %%
import numpy as np
import pandas as pd # to create dataframe and handle data manipulation
import json # to work with Json data

# %%
# Read in CSV file

df = pd.read_csv('TopIMBDmovies.csv')
df
# Out:
#                         Title                                    URL  \
# 0    The Shawshank Redemption  https://www.imdb.com/title/tt0111161/
# 1               The Godfather  https://www.imdb.com/title/tt0068646/
# 2             The Dark Knight  https://www.imdb.com/title/tt0468569/
# 3       The Godfather Part II  https://www.imdb.com/title/tt0071562/
# 4                12 Angry Men  https://www.imdb.com/title/tt0050083/
# ..                        ...                                    ...
# 245             Groundhog Day  https://www.imdb.com/title/tt0107048/
# 246                  The Help  https://www.imdb.com/title/tt1454029/
# 247        Gangs of Wasseypur  https://www.imdb.com/title/tt1954470/
# 248             Amores perros  https://www.imdb.com/title/tt0245712/
# 249                  Drishyam  https://www.imdb.com/title/tt4430212/
#
#                                            Description  Best Rating  \
# 0    A banker convicted of uxoricide forms a friend...           10
# ...

# %%
# inspecting data after loading it in dataframe
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         250 non-null    object
#  1   URL           250 non-null    object
#  2   Description   250 non-null    object
#  3   Best Rating   250 non-null    int64
#  4   Worst Rating  250 non-null    int64
#  5   Rating        250 non-null    float64
#  6   Genre         250 non-null    object
#  7   Duration      250 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 15.8+ KB
#        Best Rating  Worst Rating      Rating
# count        250.0         250.0  250.000000
# mean          10.0           1.0    8.308000
# std            0.0           0.0    0.231496
# min           10.0           1.0    8.000000
# 25%           10.0           1.0    8.100000
# 50%           10.0           1.0    8.200000
# 75%           10.0           1.0    8.400000
# ...

# %%
# Identify missing values
missing_data = df.isnull().sum()
missing_data

#no missing values seen

# if there was missing values, Fill missing values with the mean of the column using below syntax
#df['column'].fillna(df['column'].mean(), inplace=True)

# %%
# Remove duplicates based on specific columns
remove_dup = df.drop_duplicates(subset=['Title', 'URL'])
remove_dup
# no duplicates movie found
# Out:
#                         Title                                    URL  \
# 0    The Shawshank Redemption  https://www.imdb.com/title/tt0111161/
# 1               The Godfather  https://www.imdb.com/title/tt0068646/
# 2             The Dark Knight  https://www.imdb.com/title/tt0468569/
# 3       The Godfather Part II  https://www.imdb.com/title/tt0071562/
# 4                12 Angry Men  https://www.imdb.com/title/tt0050083/
# ..                        ...                                    ...
# 245             Groundhog Day  https://www.imdb.com/title/tt0107048/
# 246                  The Help  https://www.imdb.com/title/tt1454029/
# 247        Gangs of Wasseypur  https://www.imdb.com/title/tt1954470/
# 248             Amores perros  https://www.imdb.com/title/tt0245712/
# 249                  Drishyam  https://www.imdb.com/title/tt4430212/
#
#                                            Description  Best Rating  \
# 0    A banker convicted of uxoricide forms a friend...           10
# ...

# %%
# Correct data types
df['Best Rating'] = df['Best Rating'].astype(int)
df['Worst Rating'] = df['Worst Rating'].astype(int)
df['Rating'] = df['Rating'].astype(float)
print (df.head())
# Out:
#                       Title                                    URL  \
# 0  The Shawshank Redemption  https://www.imdb.com/title/tt0111161/
# 1             The Godfather  https://www.imdb.com/title/tt0068646/
# 2           The Dark Knight  https://www.imdb.com/title/tt0468569/
# 3     The Godfather Part II  https://www.imdb.com/title/tt0071562/
# 4              12 Angry Men  https://www.imdb.com/title/tt0050083/
#
#                                          Description  Best Rating  \
# 0  A banker convicted of uxoricide forms a friend...           10
# 1  The aging patriarch of an organized crime dyna...           10
# 2  When a menace known as the Joker wreaks havoc ...           10
# 3  The early life and career of Vito Corleone in ...           10
# 4  The jury in a New York City murder trial is fr...           10
#
#    Worst Rating  Rating                 Genre Duration
# 0             1     9.3                 Drama  PT2H22M
# ...

# %%
# Remove outliers if there are any
#df = df[df['Best Rating'] < df['Best Rating'].quantile(0.95)]
#df = df[df['Worst Rating'] < df['Worst Rating'].quantile(0.95)]
#df = df[df['Rating'] < df['Rating'].quantile(0.95)]
#print (df.head())
# Out:
# Empty DataFrame
# Columns: [Title, URL, Description, Best Rating, Worst Rating, Rating, Genre, Duration]
# Index: []

# %%
print (df.head())
# Out:
#                                     Title  \
# 0                The Shawshank Redemption
# 1                           The Godfather
# 2                         The Dark Knight
# 3                   The Godfather Part II
# 4                            12 Angry Men
# ..                                    ...
# 95  Eternal Sunshine of the Spotless Mind
# 96                  2001: A Space Odyssey
# 97                              Incendies
# 98                         Reservoir Dogs
# 99                          The Apartment
#
#                                       URL  \
# 0   https://www.imdb.com/title/tt0111161/
# 1   https://www.imdb.com/title/tt0068646/
# 2   https://www.imdb.com/title/tt0468569/
# 3   https://www.imdb.com/title/tt0071562/
# 4   https://www.imdb.com/title/tt0050083/
# ..                                    ...
# 95  https://www.imdb.com/title/tt0338013/
# 96  https://www.imdb.com/title/tt0062622/
# 97  https://www.imdb.com/title/tt1255953/
# ...
